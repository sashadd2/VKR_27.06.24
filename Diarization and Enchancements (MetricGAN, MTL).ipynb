# %%
# !nvidia-smi
# Out:
# Fri Mar  1 16:54:40 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 537.13                 Driver Version: 537.13       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   54C    P8               5W /  60W |      0MiB /  4096MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.1.0+cu118
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: C:\Users\sasha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, typing-extensions
# Required-by: asteroid-filterbanks, julius, lightning, pyannote.audio, pytorch-lightning, pytorch-metric-learning, speechbrain, torch-audiomentations, torch-pitch-shift, torchaudio, torchmetrics, torchvision, voicefixer

# %%
# !pip uninstall torch

# %%
# !pip uninstall torchaudio

# %%
# !pip uninstall torchvision

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB 217.9 kB/s eta 3:09:15
#      ---------------------------------------- 0.0/2.5 GB 435.7 kB/s eta 1:34:38
#      ---------------------------------------- 0.0/2.5 GB 381.3 kB/s eta 1:48:09
#      ---------------------------------------- 0.0/2.5 GB 607.9 kB/s eta 1:07:50
#      ---------------------------------------- 0.0/2.5 GB 726.2 kB/s eta 0:56:47
#      ---------------------------------------- 0.0/2.5 GB 948.8 kB/s eta 0:43:28
#      ---------------------------------------- 0.0/2.5 GB 1.1 MB/s eta 0:37:45
#      ---------------------------------------- 0.0/2.5 GB 1.5 MB/s eta 0:27:24
#      ---------------------------------------- 0.0/2.5 GB 1.8 MB/s eta 0:22:29
# ...

# %%
# !pip install cuda-python
# Out:
# ...
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB 435.7 kB/s eta 0:00:24
#    ---------------------------------------- 0.0/10.2 MB 393.8 kB/s eta 0:00:26
#    ---------------------------------------- 0.0/10.2 MB 393.8 kB/s eta 0:00:26
#    ---------------------------------------- 0.1/10.2 MB 416.7 kB/s eta 0:00:25
#    ---------------------------------------- 0.1/10.2 MB 350.1 kB/s eta 0:00:29
#    ---------------------------------------- 0.1/10.2 MB 350.1 kB/s eta 0:00:29
#    ---------------------------------------- 0.1/10.2 MB 344.8 kB/s eta 0:00:30
#    ---------------------------------------- 0.1/10.2 MB 327.4 kB/s eta 0:00:31
#     --------------------------------------- 0.1/10.2 MB 315.4 kB/s eta 0:00:32
# ...

# %%
torch.__version__
# Out:
# '2.1.0+cu121'

# %%
import torch
import torchvision
torch.cuda.is_available()
# Out:
# True

# %%
# for speechbrain
# !pip install speechbrain

# pyannote.audio
# !pip install pyannote.audio

#!pip install -qq pytorch

# %%
# !pip install --upgrade pyannote.audio
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# DEPRECATION: voicefixer 0.1.2 has a non-standard dependency specifier streamlit>=1.12.0pyyaml. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of voicefixer or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import glob, sys, os
import torch
import torchaudio
import datetime
import time

from speechbrain.inference.enhancement import WaveformEnhancement
from speechbrain.inference.enhancement import SpectralMaskEnhancement
from speechbrain.dataio.dataio import read_audio

from IPython.display import Audio
from IPython.core.display import display

from pyannote.audio import Pipeline
pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization-3.0", use_auth_token="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")

mainPath = "C:/Users/sasha/OneDrive/Desktop/НИР/New Research/"
filesDirStr = "audio/normalized/"
diarDirStr = "DIARIZED/"
directory_files = os.listdir(mainPath + filesDirStr)

enhance_model_MTL = WaveformEnhancement.from_hparams(
    source="speechbrain/mtl-mimic-voicebank",
    savedir="pretrained_models/mtl-mimic-voicebank",
    run_opts={"device":"cuda"}
)

enhance_model_MetricGAN = SpectralMaskEnhancement.from_hparams(
    source="speechbrain/metricgan-plus-voicebank",
    savedir="pretrained_models/metricgan-plus-voicebank",
    run_opts={"device":"cuda"}
)
# Out:
# C:\Users\sasha\AppData\Local\Temp\ipykernel_8688\1943551305.py:12: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display
# C:\Users\sasha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyannote\audio\core\io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# C:\Users\sasha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch_audiomentations\utils\io.py:27: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")

# %%
directory_files
# Out:
# ['1.wav',
#  '10.wav',
#  '100.wav',
#  '11.wav',
#  '12.wav',
#  '13.wav',
#  '14.wav',
#  '15.wav',
#  '16.wav',
#  '17.wav',
#  '18.wav',
#  '19.wav',
#  '2.wav',
#  '20.wav',
#  '21.wav',
#  '22.wav',
#  '23.wav',
#  '24.wav',
#  '25.wav',
#  '26.wav',
#  '27.wav',
#  '28.wav',
#  '29.wav',
#  '3.wav',
#  '30.wav',
#  '31.wav',
#  '32.wav',
#  '33.wav',
#  '34.wav',
#  '35.wav',
#  '36.wav',
#  '37.wav',
#  '38.wav',
#  '39.wav',
#  '4.wav',
#  '40.wav',
#  '41.wav',
#  '42.wav',
#  '43.wav',
#  '44.wav',
#  '45.wav',
#  '46.wav',
#  '47.wav',
#  '48.wav',
#  '49.wav',
#  '5.wav',
#  '50.wav',
#  '51.wav',
#  '52.wav',
#  '53.wav',
#  '54.wav',
#  '55.wav',
#  '56.wav',
#  '57.wav',
#  '58.wav',
#  '59.wav',
#  '6.wav',
#  '60.wav',
#  '61.wav',
#  '62.wav',
#  '63.wav',
#  '64.wav',
#  '65.wav',
#  '66.wav',
#  '67.wav',
#  '68.wav',
#  '69.wav',
#  '7.wav',
#  '70.wav',
#  '71.wav',
#  '72.wav',
#  '73.wav',
#  '74.wav',
#  '75.wav',
#  '76.wav',
#  '77.wav',
#  '78.wav',
# ...

# %%
class Turn(object):
    """Speaker turn class.
    A turn represents a segment of audio attributed to a single speaker.
    Parameters
    ----------
    onset : float
        Onset of turn in seconds from beginning of recording.
    offset : float, optional
        Offset of turn in seconds from beginning of recording. If None, then
        computed from ``onset`` and ``dur``.
        (Default: None)
    dur : float, optional
        Duration of turn in seconds. If None, then computed from ``onset`` and
        ``offset``.
        (Default: None)
    speaker_id : str, optional
        Speaker id.
        (Default: None)
    file_id : str, optional
        File id.
        (Default: none)
    """
    def __init__(self, onset, offset=None, dur=None, speaker_id=None,
                 file_id=None):
        if not (bool(offset is None) != bool(dur is None)):
            raise ValueError('Exactly one of offset or dur must be given')
        if onset < 0:
            raise ValueError('Turn onset must be >= 0 seconds')
        if offset:
            dur = offset - onset
        if dur <= 0:
            raise ValueError('Turn duration must be > 0 seconds')
        if not offset:
            offset = onset + dur
        self.onset = onset
        self.offset = offset
        self.dur = dur
        self.speaker_id = speaker_id
        self.file_id = file_id

    def __eq__(self, other):
        if isinstance(other, self.__class__):
            return self.__dict__ == other.__dict__
        return False

    def __ne__(self, other):
        return not self.__eq__(other)

    def __hash__(self):
        return hash((self.onset, self.offset, self.dur, self.file_id,
                     self.speaker_id))

    def __str__(self):
        return ('FILE: %s, SPEAKER: %s, ONSET: %f, OFFSET: %f, DUR: %f' %
                (self.file_id, self.speaker_id, self.onset, self.offset,
                 self.dur))

    def __repr__(self):
        speaker_id = ("'%s'" % self.speaker_id if self.speaker_id is not None
                      else None)
        file_id = ("'%s'" % self.file_id if self.file_id is not None
                   else None)
        return ('Turn(%f, %f, None, %s, %s)' %
                (self.onset, self.offset, speaker_id, file_id))

def _parse_rttm_line(line):
    line = line.decode('utf-8').strip()
    fields = line.split()
    if len(fields) < 9:
        raise IOError('Number of fields < 9. LINE: "%s"' % line)
    file_id = fields[1]
    speaker_id = fields[7]

    # Check valid turn onset.
    try:
        onset = float(fields[3])
    except ValueError:
        raise IOError('Turn onset not FLOAT. LINE: "%s"' % line)
    if onset < 0:
        raise IOError('Turn onset < 0 seconds. LINE: "%s"' % line)

    # Check valid turn duration.
    try:
        dur = float(fields[4])
    except ValueError:
        raise IOError('Turn duration not FLOAT. LINE: "%s"' % line)
    if dur <= 0:
        raise IOError('Turn duration <= 0 seconds. LINE: "%s"' % line)

    return Turn(onset, dur=dur, speaker_id=speaker_id, file_id=file_id)

def load_rttm(rttmf):
  with open(rttmf, 'rb') as f:
      turns = []
      speaker_ids = set()
      file_ids = set()
      for line in f:
          if line.startswith(b'SPKR-INFO'):
              continue
          turn = _parse_rttm_line(line)
          turns.append(turn)
          speaker_ids.add(turn.speaker_id)
          file_ids.add(turn.file_id)
  return turns, speaker_ids, file_ids

def generate_ffmpeg_mute_command(fonset, foffset):
  if foffset == 0:
    string = 'volume=enable=\'between(t,0,' + str(fonset) + ')\':volume=0'
  if fonset == 0:
    string = ', volume=enable=\'between(t,' + str(foffset) + ',100000)\':volume=0"'
  if fonset != 0 and foffset != 0:
    string = ', volume=enable=\'between(t,' + str(foffset) + ',' + str(fonset) + ')\':volume=0'
  return string

def getWavFilesFromFolder(dirPath):
	files = glob.glob(dirPath+os.sep+'*.wav')
	return files

# %%
Функция, которая проводит разделение аудиофайла на аудиофайлы соответствующие своим акторам.

filename - название аудиофайла с расширением wav. 
    Аудиофайл должен быть загружен в папку Files.

ВНИМАНИЕ: В НАЗВАНИИ ФАЙЛА НЕ ДОЛЖНО БЫТЬ ПРОБЕЛОВ

enhanceType - тип улучшения качества аудио. 
"Pure" - без улучшений, 
"MTL" - улучшение моделью MTL, 
"MetricGAN" - улучшение моделью MetricGAN, 
"MTL_MetricGAN" - Улучшение МТЛ-МетрикГАН, 
"MetricGAN_MTL" - Улучшение МетрикГАН-МТЛ.

# %%
for files in directory_files:
    filePath = mainPath + filesDirStr + files
    filePathEnhanced = mainPath + "audio/"
    
    print(files)
    
    #if enhanceType == "MTL":
    strMTL = "MTL_normalized"
    pathMTL = filePathEnhanced + strMTL
    if not os.path.exists(pathMTL):
        os.mkdir(pathMTL)
    enhanced = enhance_model_MTL.enhance_file(filePath)
    torchaudio.save(pathMTL + "/" + files, enhanced.unsqueeze(0).cpu(), 16000)
    print("Улучшение  МТЛ - успешно")
      
    #elif enhanceType == "MetricGAN":
    strMetricGAN = "MetricGAN_normalized"
    pathMetricGAN = filePathEnhanced + strMetricGAN
    if not os.path.exists(pathMetricGAN):
        os.mkdir(pathMetricGAN)
    enhanced = enhance_model_MetricGAN.enhance_file(filePath)
    torchaudio.save(pathMetricGAN + "/" + files, enhanced.unsqueeze(0).cpu(), 16000)
    print("Улучшение  МетрикГАН - успешно")
      
    #elif enhanceType == "MTL_MetricGAN":
    strMTLMetricGAN = "MTL_MetricGAN_normalized"
    pathMTLMetricGAN = filePathEnhanced + strMTLMetricGAN
    if not os.path.exists(pathMTLMetricGAN):
        os.mkdir(pathMTLMetricGAN)
    enhanced = enhance_model_MetricGAN.enhance_file(pathMTL + "/" + files)
    torchaudio.save(pathMTLMetricGAN + "/" + files, enhanced.unsqueeze(0).cpu(), 16000)
    print("Улучшение  МТЛ-МетрикГАН - успешно")
      
    #elif enhanceType == "MetricGAN_MTL":
    strMetricGANMTL = "MetricGAN_MTL_normalized"
    pathMetricGANMTL = filePathEnhanced + strMetricGANMTL
    if not os.path.exists(pathMetricGANMTL):
        os.mkdir(pathMetricGANMTL)
    enhanced = enhance_model_MTL.enhance_file(pathMetricGAN + "/" + files)
    torchaudio.save(pathMetricGANMTL + "/" + files, enhanced.unsqueeze(0).cpu(), 16000)
    print("Улучшение  МетрикГАН-МТЛ - успешно")
# Out:
# 15.wav
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[6], line 12
#      10 if not os.path.exists(pathMTL):
#      11     os.mkdir(pathMTL)
# ---> 12 enhanced = enhance_model_MTL.enhance_file(filePath)
#      13 torchaudio.save(pathMTL + "/" + files, enhanced.unsqueeze(0).cpu(), 16000)
#      14 print("Улучшение  МТЛ - успешно")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\speechbrain\inference\enhancement.py:173, in WaveformEnhancement.enhance_file(self, filename, output_filename, **kwargs)
#     171 # Fake a batch:
#     172 batch = noisy.unsqueeze(0)
# --> 173 enhanced = self.enhance_batch(batch)
#     175 if output_filename is not None:
#     176     torchaudio.save(
#     177         uri=output_filename,
#     178         src=enhanced,
# ...

# %%
def diarizationFunc(filename, enhanceType):
  date = str(datetime.datetime.now()).replace(":","_")
  print(date)
  filePath = mainPath + filesDirStr + filename
  tempPath = mainPath + 'audio/' + os.path.splitext(os.path.basename(filename))[0] + ' ' + date + '/'
  os.mkdir(tempPath)

  #enhance
  if enhanceType == "MTL":
    enhanced = enhance_model_MTL.enhance_file(filePath)
    filePath = tempPath + filename
    torchaudio.save(filePath, enhanced.unsqueeze(0).cpu(), 16000)
    print("Улучшение  МТЛ - успешно")
  elif enhanceType == "MetricGAN":
    enhanced = enhance_model_MetricGAN.enhance_file(filePath)
    filePath = tempPath + filename
    torchaudio.save(filePath, enhanced.unsqueeze(0).cpu(), 16000)
    print("Улучшение  МетрикГАН - успешно")
  elif enhanceType == "MTL_MetricGAN":
    enhanced = enhance_model_MTL.enhance_file(filePath)
    filePath = tempPath + filename
    torchaudio.save(filePath, enhanced.unsqueeze(0).cpu(), 16000)
    print("Улучшение  МТЛ - успешно")
    enhanced = enhance_model_MetricGAN.enhance_file(filePath)
    #Пофиксить сохранение в директорию
    filePath = filename
    torchaudio.save(filePath, enhanced.unsqueeze(0).cpu(), 16000)
    print("Улучшение  МетрикГАН - успешно")
    print("Улучшение  МТЛ-МетрикГАН - успешно")
  elif enhanceType == "MetricGAN_MTL":
    enhanced = enhance_model_MetricGAN.enhance_file(filePath)
    filePath = tempPath + filename
    torchaudio.save(filePath, enhanced.unsqueeze(0).cpu(), 16000)
    print("Улучшение  МетрикГАН - успешно")
    enhanced = enhance_model_MTL.enhance_file(filePath)
      #Пофиксить сохранение в директорию
    filePath = filename
    torchaudio.save(filePath, enhanced.unsqueeze(0).cpu(), 16000)
    print("Улучшение  МТЛ - успешно")
    print("Улучшение  МетрикГАН-МТЛ - успешно")


  #diarization
  diarization = pipeline(filePath)
  rttmPath = mainPath + diarDirStr + os.path.splitext(os.path.basename(filename))[0] + enhanceType + '.rttm'
  with open(rttmPath, "w") as rttm:
      diarization.write_rttm(rttm)
  print("Текстовая диаризация - успешно")

# %%
"Pure" - без улучшений,
"MTL" - улучшение моделью MTL,
"MetricGAN" - улучшение моделью MetricGAN,
"MTL_MetricGAN" - Улучшение МТЛ-МетрикГАН,
"MetricGAN_MTL" - Улучшение МетрикГАН-МТЛ.

# %%
for files in directory_files:
  diarizationFunc(files, "MetricGAN")
for files in directory_files:
  diarizationFunc(files, "MTL_MetricGAN")
for files in directory_files:
  diarizationFunc(files, "MetricGAN_MTL")
# Out:
# 2023-09-28 14_20_49.608527
# Улучшение  МетрикГАН - успешно
# Текстовая диаризация - успешно
# 2023-09-28 14_21_12.675166
# Улучшение  МетрикГАН - успешно
# Текстовая диаризация - успешно
# 2023-09-28 14_21_47.210855
# Улучшение  МетрикГАН - успешно
# Текстовая диаризация - успешно
# 2023-09-28 14_22_28.258423
# Улучшение  МетрикГАН - успешно
# Текстовая диаризация - успешно
# 2023-09-28 14_23_16.778427
# Улучшение  МетрикГАН - успешно
# Текстовая диаризация - успешно
# 2023-09-28 14_24_02.910577
# Улучшение  МетрикГАН - успешно
# Текстовая диаризация - успешно
# 2023-09-28 14_25_11.449235
# Улучшение  МетрикГАН - успешно
# Текстовая диаризация - успешно
# 2023-09-28 14_26_23.033436
# Улучшение  МетрикГАН - успешно
# Текстовая диаризация - успешно
# 2023-09-28 14_26_43.613436
# Улучшение  МетрикГАН - успешно
# Текстовая диаризация - успешно
# 2023-09-28 14_27_09.218945
# Улучшение  МетрикГАН - успешно
# Текстовая диаризация - успешно
# 2023-09-28 14_28_20.768873
# ...

# %%
pipeline.device
# Out:
# device(type='cuda')

# %%
import glob, sys, os
import torchaudio
import datetime
import time
import torch

from IPython.display import Audio
from IPython import display

from pyannote.audio import Pipeline
pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization-3.1", use_auth_token="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")
pipeline.to(torch.device("cuda"))

mainPath = "C:/Users/sasha/OneDrive/Desktop/НИР/New Research/"
audioDirStr = "audio/"
diarDirStr = "diarization/"
# Out:
# C:\Users\sasha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyannote\audio\core\io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# C:\Users\sasha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch_audiomentations\utils\io.py:27: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# pytorch_model.bin:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/221 [00:00<?, ?B/s]

# %%
filePath = mainPath + audioDirStr + "default"
directory_files = os.listdir(filePath)
for file in directory_files:
    print(os.path.splitext(os.path.basename(file))[0])
# Out:
# 1
# 10
# 11
# 12
# 13
# 14
# 15
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
def diarFun(folderName):
    fileFolderPath = mainPath + audioDirStr + folderName
    rttmFolderPath = mainPath + diarDirStr + folderName
    if not os.path.exists(rttmFolderPath):
        os.mkdir(rttmFolderPath)
    directory_files = os.listdir(fileFolderPath)

    for file in directory_files:
        diarization = pipeline(fileFolderPath + '/' + file)
        rttmPath = rttmFolderPath + '/' + os.path.splitext(os.path.basename(file))[0] + '.rttm'
        with open(rttmPath, "w") as rttm:
            diarization.write_rttm(rttm)
        print("Текстовая диаризация " + file + " успешна")

# %%
allMethods = ["default","normalized","MTL","MTL_Normalized","MetricGAN","MetricGAN_Normalized",
              "MetricGAN_MTL","MetricGAN_MTL_Normalized","MTL_MetricGAN","MTL_MetricGAN_Normalized",
              "deepFilterNet1","deepFilterNet1_normalized","deepFilterNet2","deepFilterNet2_normalized",
             "deepFilterNet3","deepFilterNet3_normalized"]

choosedMethods = ["deepFilterNet1_normalized", "deepFilterNet2","deepFilterNet2_normalized", "deepFilterNet3","deepFilterNet3_normalized"]

for method in allMethods:
    diarFun(method)
# Out:
# Текстовая диаризация 1.wav успешна
# Текстовая диаризация 10.wav успешна
# Текстовая диаризация 11.wav успешна
# Текстовая диаризация 12.wav успешна
# Текстовая диаризация 13.wav успешна
# Текстовая диаризация 14.wav успешна
# Текстовая диаризация 15.wav успешна
# Текстовая диаризация 2.wav успешна
# Текстовая диаризация 3.wav успешна
# Текстовая диаризация 4.wav успешна
# Текстовая диаризация 5.wav успешна
# Текстовая диаризация 6.wav успешна
# Текстовая диаризация 7.wav успешна
# Текстовая диаризация 8.wav успешна
# Текстовая диаризация 9.wav успешна
# Текстовая диаризация 1.wav успешна
# Текстовая диаризация 10.wav успешна
# Текстовая диаризация 11.wav успешна
# Текстовая диаризация 12.wav успешна
# Текстовая диаризация 13.wav успешна
# Текстовая диаризация 14.wav успешна
# Текстовая диаризация 15.wav успешна
# Текстовая диаризация 2.wav успешна
# Текстовая диаризация 3.wav успешна
# Текстовая диаризация 4.wav успешна
# Текстовая диаризация 5.wav успешна
# ...

# %%
# !pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# DEPRECATION: voicefixer 0.1.2 has a non-standard dependency specifier streamlit>=1.12.0pyyaml. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of voicefixer or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
mainPath = "C:/Users/sasha/OneDrive/Desktop/НИР/New Research/new_audio/"
default = "default"
norm = "normalized"

defPath =  default + "/"
normPath = norm + "/"

directory_files_default = os.listdir(mainPath + defPath)
directory_files_normalized = os.listdir(mainPath + normPath)

# %%
directory_files_default
# Out:
# ['92.wav',
#  '93.wav',
#  '94.wav',
#  '95.wav',
#  '96.wav',
#  '97.wav',
#  '98.wav',
#  '99.wav']

# %%
from pydub import AudioSegment
import gc
import torch

split_duration = 60 * 1000 * 3

def sepEnch(filePath, enchPath, file, enhanceType):
    # Define the path to your input audio file
    input_audio_path = filePath
    # Define the path to the enhanced audio file
    enhanced_audio_path = enchPath + "/" + files
    audio = AudioSegment.from_file(input_audio_path)
    segments = []
    # Split the audio into segments
    for i in range(0, len(audio), split_duration):
        segment = audio[i:i + split_duration]
        segments.append(segment)
    output_enhanced_speech = []
    for i, segment in enumerate(segments):
        temp_path = f'temp_segment_{i}.wav'
        segment.export(temp_path, format='wav')
        if (enhanceType == "MTL" or enhanceType == "MetricGAN_MTL" or enhanceType == "MTL_Normalized" or enhanceType == "MetricGAN_MTL_Normalized"):
            enhanced_speech = enhance_model_MTL.enhance_file(temp_path)
        elif (enhanceType == "MTL_MetricGAN" or enhanceType == "MetricGAN" or enhanceType == "MTL_MetricGAN_Normalized" or enhanceType == "MetricGAN_Normalized"):
            enhanced_speech = enhance_model_MetricGAN.enhance_file(temp_path)
        output_enhanced_speech.append(enhanced_speech.unsqueeze(0).cpu())
        # Clean up the temporary file
        os.remove(temp_path)

    # Concatenate the enhanced speech segments along the time dimension
    enhanced_speech_cummulative = torch.cat(output_enhanced_speech, dim=1)
    audio_data = torch.flatten(enhanced_speech_cummulative,start_dim=1)
    torchaudio.save(enhanced_audio_path, audio_data, 16000)

# %%
for files in directory_files_default:
    filePath = mainPath + defPath + files
    filePathEnhanced = mainPath


    #if enhanceType == "MTL_Normalized":
    strMTL = "MTL"
    pathMTL = filePathEnhanced + strMTL
    if not os.path.exists(pathMTL):
        os.mkdir(pathMTL)
    sepEnch(filePath, pathMTL, files, strMTL)
    print("Улучшение  МТЛ - успешно")

    #elif enhanceType == "MTL_MetricGAN":
    strMTLMetricGAN = "MTL_MetricGAN"
    pathMTLMetricGAN = filePathEnhanced + strMTLMetricGAN
    if not os.path.exists(pathMTLMetricGAN):
        os.mkdir(pathMTLMetricGAN)
    sepEnch(pathMTL + "/" + files, pathMTLMetricGAN, files, strMTLMetricGAN)
    print("Улучшение  МТЛ-МетрикГАН - успешно")

    #elif enhanceType == "MetricGAN":
    strMetricGAN = "MetricGAN"
    pathMetricGAN = filePathEnhanced + strMetricGAN
    if not os.path.exists(pathMetricGAN):
        os.mkdir(pathMetricGAN)
    sepEnch(filePath, pathMetricGAN, files, strMetricGAN)
    print("Улучшение  МетрикГАН - успешно")

    #elif enhanceType == "MetricGAN_MTL":
    strMetricGANMTL = "MetricGAN_MTL"
    pathMetricGANMTL = filePathEnhanced + strMetricGANMTL
    if not os.path.exists(pathMetricGANMTL):
        os.mkdir(pathMetricGANMTL)
    sepEnch(pathMetricGAN + "/" + files, pathMetricGANMTL, files, strMetricGANMTL)
    print("Улучшение  МетрикГАН-МТЛ - успешно")
# Out:
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# ...

# %%
for files in directory_files_normalized:
    filePath = mainPath + normPath + files
    filePathEnhanced = mainPath


    #if enhanceType == "MTL_Normalized":
    strMTL = "MTL_Normalized"
    pathMTL = filePathEnhanced + strMTL
    if not os.path.exists(pathMTL):
        os.mkdir(pathMTL)
    sepEnch(filePath, pathMTL, files, strMTL)
    print("Улучшение  МТЛ - успешно")

    #elif enhanceType == "MTL_MetricGAN":
    strMTLMetricGAN = "MTL_MetricGAN_Normalized"
    pathMTLMetricGAN = filePathEnhanced + strMTLMetricGAN
    if not os.path.exists(pathMTLMetricGAN):
        os.mkdir(pathMTLMetricGAN)
    sepEnch(pathMTL + "/" + files, pathMTLMetricGAN, files, strMTLMetricGAN)
    print("Улучшение  МТЛ-МетрикГАН - успешно")

    #elif enhanceType == "MetricGAN":
    strMetricGAN = "MetricGAN_Normalized"
    pathMetricGAN = filePathEnhanced + strMetricGAN
    if not os.path.exists(pathMetricGAN):
        os.mkdir(pathMetricGAN)
    sepEnch(filePath, pathMetricGAN, files, strMetricGAN)
    print("Улучшение  МетрикГАН - успешно")

    #elif enhanceType == "MetricGAN_MTL":
    strMetricGANMTL = "MetricGAN_MTL_Normalized"
    pathMetricGANMTL = filePathEnhanced + strMetricGANMTL
    if not os.path.exists(pathMetricGANMTL):
        os.mkdir(pathMetricGANMTL)
    sepEnch(pathMetricGAN + "/" + files, pathMetricGANMTL, files, strMetricGANMTL)
    print("Улучшение  МетрикГАН-МТЛ - успешно")
# Out:
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# Улучшение  МТЛ-МетрикГАН - успешно
# Улучшение  МетрикГАН - успешно
# Улучшение  МетрикГАН-МТЛ - успешно
# Улучшение  МТЛ - успешно
# ...
